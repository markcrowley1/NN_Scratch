# %% [markdown]
# # Basic Neural Network: Built From Scratch
#
# In this notebook I want to build a very simple neural network, using only vanilla Python and Numpy, so that we can fully understand every mathematical step in the process.
#
# The main focus of this exercise is to illustrate how a network learns a dataset and can be used to make a prediction. To do that we will train our network to behave as a cubic function over a fixed range. To keep things simple, we won't concern ourselves with how the model performs on unseen data.
#
# First, we import the packages we need for mathematical operations and plotting graphs.

# %%
# Import packages
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Next, we generate a set of inputs (x) in the range [-10, 10] and compute corresponding output values (y) using a cubic function.

# %%
# Generate a dataset - a normal distribution
x = np.arange(-10,10,0.01)
y = (x**3 + 10*(x**2) + 5*x + 100)/1000

plt.plot(x, y)
plt.title("Cubic Function")
plt.xlabel("Input (x)")
plt.ylabel("Output (y)")
plt.show()

# %%
class Neuron:
    def __init__(self, num_inputs: int):
        # Weights and bias initialised to random value
        self.weights = np.random.rand(num_inputs)
        self.bias = np.random.rand()
        # a and z value set randomly (not important, could be set to None)
        self.a = np.random.rand()
        self.z = np.random.rand()
        # weight and bias gradients set randomly (also not important)
        self.weight_grad = np.random.rand(num_inputs)
        self.bias_grad = np.random.rand()
        self.num_inputs = num_inputs
        
    def initialise_parameters(self):
        """ Initialise Weights and Bias Corresponding to this Neuron """
        self.weights = None
        self.bias = None

    def compute_output(self):
        """ Compute z value for this neuron """
        pass

    def ReLU(self):
        """ Activation Function """
        pass

class Layer:
    def __init__(self):
        self.neurons = [Neuron()]

class Network:
    def __init__(self):
        pass
